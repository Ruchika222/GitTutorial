# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruchika222/GitTutorial/blob/master/Cricket_IPL_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Most Runs - 2020.csv")

# %%
df1 = pd.read_csv("Most Runs - 2021.csv")

# %%
df2 = pd.read_csv("Most Runs - 2022.csv")

# %%
final_df=pd.concat([df,df1,df2])

# %%
final_df.head()
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2    3    David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3    4    Shreyas Iyer   17    17   2   519   88*   34.6  421  123.27    0
# 4    5    Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12
# 2   4  52  14
# 3   3  40  16
# 4   4  36  30

# %%
final_df.describe()
# Out:
#               POS         Mat        Inns          NO        Runs          BF  \
# count  444.000000  444.000000  444.000000  444.000000  444.000000  444.000000
# mean    74.975225    9.092342    6.689189    1.547297  133.504505  101.788288
# std     43.579375    5.036484    4.859448    1.654058  160.479044  116.589381
# min      1.000000    1.000000    1.000000    0.000000    0.000000    1.000000
# 25%     37.750000    5.000000    2.000000    0.000000   11.750000   12.750000
# 50%     74.500000    9.000000    5.000000    1.000000   58.000000   47.000000
# 75%    111.250000   14.000000   11.000000    2.000000  224.000000  166.250000
# max    162.000000   17.000000   17.000000   10.000000  863.000000  579.000000
#
#                SR         100          50          4s          6s
# count  444.000000  444.000000  444.000000  444.000000  444.000000
# mean   111.348221    0.038288    0.695946   11.592342    5.592342
# std     45.947765    0.270227    1.249788   15.339294    7.282003
# ...

# %%
final_df.isna().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
#There are total 234 palyers
final_df.Player.nunique()
# Out:
# 234

# %%
final_df.Mat.max()
# Out:
# 17

# %%
final_df[final_df['Mat']==17]
# Out:
#      POS               Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 1      2       Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 3      4         Shreyas Iyer   17    17   2   519   88*   34.6  421  123.27
# 19    20       Marcus Stoinis   17    17   3   352    65  25.14  237  148.52
# 67    68        Kagiso Rabada   17     8   4    56   15*   14.0   49  114.28
# 7      8         Shubman Gill   17    17   0   478    57  28.11  402  118.90
# 12    13       Rahul Tripathi   17    16   2   397   74*  28.35  283  140.28
# 13    14          Nitish Rana   17    16   3   383    80  29.46  314  121.97
# 31    32       Dinesh Karthik   17    15   5   223    40   22.3  170  131.17
# 46    47          Eoin Morgan   17    16   4   133   47*  11.08  139   95.68
# 131  132  Varun Chakaravarthy   17     3   2     2    2*    2.0    4   50.00
# 0      1          Jos Buttler   17    17   2   863   116  57.53  579  149.05
# ...

# %%
final_df['Runs'].max()
# Out:
# 863

# %%
#Jos Buttler has scored maximum Runs
final_df[final_df['Runs']==863]
# Out:
#    POS       Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  50  \
# 0    1  Jos Buttler   17    17   2   863  116  57.53  579  149.05    4   4
#
#    4s  6s
# 0  83  45

# %%
final_df['HS'].max()
# Out:
# '99*'

# %%
final_df[final_df['HS']=='99*']
# Out:
#    POS          Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  50  \
# 8    9  Mayank Agarwal   12    12   1   441  99*  40.09  314  140.44    0   4
#
#    4s  6s
# 8  42  18

# %%
type(final_df['Avg'])
# Out:
# pandas.core.series.Series

# %%
final_df['100'].max()
# Out:
# 4

# %%
#Maximum times Jos Buttler has scored 100's
final_df[final_df['100']==4]
# Out:
#    POS       Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  50  \
# 0    1  Jos Buttler   17    17   2   863  116  57.53  579  149.05    4   4
#
#    4s  6s
# 0  83  45

# %%
final_df['50'].max()
# Out:
# 6

# %%
final_df[final_df['50']==6]
# Out:
#    POS          Player  Mat  Inns  NO  Runs   HS    Avg   BF     SR  100  50  \
# 1    2  Faf du Plessis   16    16   2   633  95*  45.21  458  138.2    0   6
# 2    3        KL Rahul   13    13   3   626  98*   62.6  451  138.8    0   6
# 4    5   Glenn Maxwell   15    14   2   513   78  42.75  356  144.1    0   6
#
#    4s  6s
# 1  60  23
# 2  48  30
# 4  48  21

# %%
final_df['4s'].max()
# Out:
# 83

# %%
#maximum 4's are scored by Jos Buttler
final_df[final_df['4s']==83]
# Out:
#    POS       Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  50  \
# 0    1  Jos Buttler   17    17   2   863  116  57.53  579  149.05    4   4
#
#    4s  6s
# 0  83  45

# %%
final_df['6s'].max()
# Out:
# 45

# %%
final_df[final_df['4s']==45]
# Out:
#     POS        Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  \
# 5     6  Sanju Samson   14    14   2   484   119  40.33  354  136.72    1   2
# 1     2     K L Rahul   15    15   3   616  103*  51.33  455  135.38    2   4
# 13   14  Ishan Kishan   14    14   1   418   81*  32.15  348  120.11    0   3
#
#     4s  6s
# 5   45  17
# 1   45  30
# 13  45  11

# %%
final_df.groupby([pd.Grouper(key='Player'),'POS','Mat','Inns','Avg','100','4s','6s','SR','BF','50'])['Runs'].mean().reset_index()[:50]
# Out:
#                Player  POS  Mat  Inns    Avg  100  4s  6s      SR   BF  50  \
# 0      AB de Villiers   10   15    14   45.4    0  33  23  158.74  286   5
# 1      AB de Villiers   19   15    14   31.3    0  23  16  148.34  211   2
# 2         Aaron Finch   31   12    12  22.33    0  28   8  111.20  241   1
# 3         Aaron Finch   76    5     5   17.2    0  10   3  140.98   61   1
# 4         Abdul Samad   54   11    10  12.33    0   4   8  127.58   87   0
# 5         Abdul Samad   54   12     8   22.2    0   8   6  170.76   65   0
# 6         Abdul Samad  148    2     2      2    0   0   0   57.14    7   0
# 7      Abhijeet Tomar  149    1     1      4    0   1   0   50.00    8   0
# 8     Abhinav Manohar   70    8     7     18    0  14   3  144.00   75   0
# 9     Abhishek Sharma   13   14    14  30.43    0  47  13  133.12  320   2
# 10    Abhishek Sharma   55    8     7  16.33    0   7   4  130.66   75   0
# ...

# %%
final_df.corr(method ='pearson')
# Out:
# <ipython-input-73-ad12daa402a6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_df.corr(method ='pearson')
#            POS       Mat      Inns        NO      Runs        BF        SR  \
# POS   1.000000 -0.589298 -0.880025 -0.293273 -0.869853 -0.868763 -0.569234
# Mat  -0.589298  1.000000  0.768269  0.546695  0.585090  0.582958  0.300628
# Inns -0.880025  0.768269  1.000000  0.419161  0.878416  0.879916  0.447898
# NO   -0.293273  0.546695  0.419161  1.000000  0.238143  0.208783  0.257207
# Runs -0.869853  0.585090  0.878416  0.238143  1.000000  0.989145  0.426863
# BF   -0.868763  0.582958  0.879916  0.208783  0.989145  1.000000  0.377186
# SR   -0.569234  0.300628  0.447898  0.257207  0.426863  0.377186  1.000000
# 100  -0.220164  0.140035  0.213646  0.018666  0.398438  0.373404  0.099047
# ...

# %%
x = final_df[['Inns','BF','SR','100','50','4s','6s']]

# %%
y = final_df['Runs']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((355, 7), (89, 7), (355,), (89,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
m=model.fit(x_train,y_train)

# %%
y_hat=m.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9963373140465497

# %%
# new_output = [15,300,160,0,6,35,25]

# %%
import numpy as np

# %%
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hat)))
# Out:
# Root Mean Squared Error: 10.387925292648438
